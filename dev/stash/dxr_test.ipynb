# %% [markdown]
# # Defused XML Testing for Python DxReview

# %% [markdown]
# ### Imports

# %%
from defusedxml import ElementTree as ET
import pandas as pd

# %% [markdown]
# ### Constants

# %%
xml_path = 'test.xml'
bad_root_xml_path = 'bad_root.xml'
proj_info_output = 'proj_info_output.xlsx'

# %% [markdown]
# ### Parsing and Exploration
# Parse the XML file, get the root element and explore the structure

# %%
doc = ET.parse(xml_path)
root = doc.getroot()

# %%
print(f'Root tag: {root.tag}')
print(f'Root attributes: {root.attrib}')
# Out:
# Root tag: ProjNet
# Root attributes: {}

# %%
def verify_root(root):
    try:
        if root.tag.lower() == 'projnet':
            return True
        else:
            return False
    except:
        return False

# %%
print(verify_root(root))
# Out:
# True

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# DrChecks {}
# Comments {}

# %% [markdown]
# ### Create startup methods

# %%
def get_root(path):
    try:
        root = ET.parse(path).getroot()
        if root.tag.lower() == 'projnet':
            return root
    except:
        pass

# %%
root2 = get_root(xml_path)
print(root2.tag, type(root2))
# Out:
# ProjNet <class 'xml.etree.ElementTree.Element'>

# %%
bad_root = get_root(bad_root_xml_path)
print(bad_root, type(bad_root))
# Out:
# None <class 'NoneType'>

# %% [markdown]
# ### DrChecks Element - Project Information Element
# The \<DrChecks> is always first under the root element \<ProjNet>, therefore, to make the code more readable, we can assign constants

# %%
drchecks_index = 0
comments_index = 1

# %%
proj_info_element = root[drchecks_index]

# %%
for child in proj_info_element:
    print(child.tag, child.text, child.attrib)
# Out:
# ProjectID 069848 {}
# ProjectControlNbr 511143 {}
# ProjectName P530 Aircraft Intermediate Maintenance Facility, Kadena AB {}
# ReviewID 235411 {}
# ReviewName Concept Design Resubmittal {}

# %% [markdown]
# ##### Read Project Info into a Dictionary

# %%
proj_info = {}

# %%
for child in proj_info_element:
    proj_info[child.tag] = child.text

# %%
proj_info
# Out:
# {'ProjectID': '069848',
#  'ProjectControlNbr': '511143',
#  'ProjectName': 'P530 Aircraft Intermediate Maintenance Facility, Kadena AB',
#  'ReviewID': '235411',
#  'ReviewName': 'Concept Design Resubmittal'}

# %%
proj_info['ProjectName']
# Out:
# 'P530 Aircraft Intermediate Maintenance Facility, Kadena AB'

# %% [markdown]
# ##### Remap the keys in the dictionary to more human readable language

# %%
key_remap = {
    'ProjectID': 'Project ID',
    'ProjectControlNbr': 'Project Control Number',
    'ProjectName': 'Project Name',
    'ReviewID': 'Review ID',
    'ReviewName': 'Review Name'
}

# %%
proj_info = {key_remap[i]:proj_info[i] for i in proj_info}
proj_info
# Out:
# {'Project ID': '069848',
#  'Project Control Number': '511143',
#  'Project Name': 'P530 Aircraft Intermediate Maintenance Facility, Kadena AB',
#  'Review ID': '235411',
#  'Review Name': 'Concept Design Resubmittal'}

# %%
df = pd.DataFrame(proj_info.items())
df.columns = ['Parameter', 'Value']
df
# Out:
#                 Parameter                                              Value
# 0              Project ID                                             069848
# 1  Project Control Number                                             511143
# 2            Project Name  P530 Aircraft Intermediate Maintenance Facilit...
# 3               Review ID                                             235411
# 4             Review Name                         Concept Design Resubmittal

# %%
df.to_excel(proj_info_output, index=False, header=False)

# %% [markdown]
# ## Comment Extraction

# %%
comments_element = root[comments_index]
print(comments_element.tag, 
      '"' + comments_element.text + '"', 
      len(comments_element.text), 
      comments_element.attrib)
# Out:
# Comments "
# 					" 6 {}

# %% [markdown]
# It appears that there are no attributes for the Comments element, which is just a collection element, also the "text" element has a bunch of garbage spaces, which are remnents of the export from ProjNet's website.

# %%
child_count = len(comments_element)
child_count
# Out:
# 114

# %%
def child_count(element):
    return len(element)

# %%
print(child_count(comments_element))
# Out:
# 114

# %% [markdown]
# ### Extracting Comment Elements
# There are two main approaches:
# - Tranverse the elements
# - Extract using XPATH
#
# First, we need to understand what subelements are included in a Comment

# %%
a_comment = comments_element[0]
print(child_count(a_comment))
# Out:
# 16

# %%
all_tags = [child.tag.lower() for child in a_comment]
all_tags
# Out:
# ['id',
#  'spec',
#  'sheet',
#  'detail',
#  'critical',
#  'commenttext',
#  'attachment',
#  'docref',
#  'createdby',
#  'createdon',
#  'status',
#  'discipline',
#  'doctype',
#  'coordinatingdiscipline',
#  'evaluations',
#  'backchecks']

# %%
other_tags = []

# %%
for comment in comments_element:
    for item in comment:
        if item.tag.lower() not in all_tags:
            other_tags.append(item.tag.lower())

# %%
other_tags
# Out:
# []

# %% [markdown]
# **NOTE:**
#
# I am trying to extract the possible top level items from any given comment. So, I pull the tags from the first comment, but scan through the rest of the comments to see if there are any other tags I missed. If other_tags is not empty, then I add that element to the first comment and iterate until empty.
#
# **TODO:**
#
# I need to go to ProjNet and input comments to see what other possible element tags may be possible and include those as well... this also means, not just reviewing the XML, but also reviewing the HTML from the BidderInquiry module

# %% [markdown]
# ### Experiment iter('comment')

# %%
#for comment in comments_element.iter('comment'):
#    print(comment.find('id'))

# %%
all_comments = comments_element.findall('comment')
print(type(all_comments)==list)
# Out:
# True

# %%
for comment in all_comments:
    comment_id = comment.find('id').text
    #print(comment_id)

# %%
#import dxr_classes as dxrc
from dxr_classes import Comment, Comments

# %%
#for comment in all_comments:
#    #new_comment = Comment(id=comment.find('id').text)
#    new_comment = Comment.from_element(comment)
#    #new_comment.ID()

# %%
new_comment = Comment.from_element(all_comments[0])
new_comment.author
# Out:
# 'Yat Hung Chan'

# %%
print(new_comment.date)
type(new_comment.date)
# Out:
# 2024-04-02 11:51:00
# datetime.datetime

# %%
new_comment.evaluations
# Out:
# <Element 'evaluations' at 0x0000025842E5ABB0>

# %%
#new_comment.print_all()

# %%
#new_comment.dump()

# %%
comment_list = []
for comment in all_comments:
    this_comment = Comment(comment)
    if this_comment not in comment_list:
        comment_list.append(this_comment)

convo = Comments(comment_list)

# %%
convo.count()
# Out:
# 114

# %%
convo.dump()
# Out:
# [{'id': '10732282',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Page 927-934 and 944-951, Room Information Entered Values\n\nPlease provide justification why the People Based Rates are 0.0 cfm/person and the Area Based Rate are 0.0 cfm/ft2.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 2, 11, 51),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': 'Structural',
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842E5ABB0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E5AF70>},
#  {'id': '10732362',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please call out what kinds of piping on P-100, for examples SS, R,...etc.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 2, 13, 47),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E5B740>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E5BE70>},
#  {'id': '10732364',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': '(1) Radon piping is shown on P-130; however, the radon risers are missing on P-131B to P-131D. Please correct.\n\n(2) Please add radon piping to the symbol and abbreviation on P-001.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 2, 13, 49),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E6C680>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E6CDB0>},
#  {'id': '10734405',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Mothers Room 207 on the 2nd floor near Grid 3C is missing supply and return conditioned air.\n\nPlease correct.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 3, 10, 51),
#   'status': 'Open',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E6D580>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E6DCB0>},
#  {'id': '10734477',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'The door of Mothers Room 207 on the 2nd floor near Grid 3C is missing in the architectural background in some mechanical plans.\n\nPlease correct.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 3, 11, 20),
#   'status': 'Open',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E6E480>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E6EBB0>},
#  {'id': '10736714',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Paint Booth 119C near Grid 4B is missing the exhaust and makeup air. Moreover, it is mentioned in the air balance calculation on Page 863 of 1702 in P530 AIMF_DESIGN ANALYSIS_20240401.pdf that "Paint booth will have a designated EF with make up air unit to operate independently of bldg. HVAC."\n\nIf the required information for sizing and selecting the equipment will be available after the 35% Concept Design, please state that in the drawing with a keynote. Otherwise please provide the exhaust and makeup air to the space.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 4, 9, 34),
#   'status': 'Open',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E6F380>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E6FE20>},
#  {'id': '10736770',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'P530 AIMF_DESIGN ANALYSIS_20240401.pdf, Page 1124 of 1702,\n\nplease see attached to remove one of the duplicate paragraphs.',
#   'attachment': 'Comment_10736770.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 4, 10, 23),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842E74900>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E75030>},
#  {'id': '10736813',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'P530 AIMF_DESIGN ANALYSIS_20240401.pdf, Page 1127 of 1702, in Section 9.7, it was mentioned that "forced ducted exhaust will be provided" for radon mitigation; however, can\'t find the radon exhaust fans on plans. Please correct.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 4, 11, 46),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E75800>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E75F30>},
#  {'id': '10736816',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'On plans the point-of-use water heaters are called WH-1; however, the schedule shows it as WH2.\n\nPlease reconcile.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 4, 11, 55),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E76700>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E76E30>},
#  {'id': '10736892',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'P530 AIMF_DESIGN ANALYSIS_20240401.pdf, Page 1141 of 1702, there is a discrepancy of the usage (in minutes) of the service sink in the list vs. the table. Please see attached and correct.',
#   'attachment': 'Comment_10736892.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 4, 13, 32),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842E77600>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E77D30>},
#  {'id': '10739106',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'A few sanitary sewer drain pipes are shown encased longitudinally in structural foundation elements. Please see attached for reference.\n\nPlease coordinate with structural engineer to provide section views.',
#   'attachment': 'Comment_10739106.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 5, 14, 13),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E80540>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E80C70>},
#  {'id': '10742631',
#   'spec': 'n/a',
#   'sheet': 'P-001',
#   'detail': None,
#   'critical': 'No',
#   'text': 'EQUIPMENT NOTES, #2 says "PROVIDE 200mm (4") HIGH, CONCRETE HOUSEKEEPING PAD UNDER ALL FLOOR MOUNTED WATER HEATERS AND EQUIPMENT REQUIRING HOUSEKEEPING PADS. SEE STRUCTURAL FOR PAD REQUIREMENTS AND DETAILS."\n\nPlease revise the note from 200mm (4") to 150mm (6"), and coordinate with structural engineer to update the detail.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 9, 46),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': 'Structural',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E81440>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E81B70>},
#  {'id': '10742655',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'No need to repeat the GENERAL SHEET NOTES on P-100A to P131D. Please move them to P-001.\n\nSheet note should be specific to the sheet.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 10, 6),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E82340>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E82A70>},
#  {'id': '10742672',
#   'spec': '10-14 and 10-18',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Padmount XFMR catalog sheet noted that "Basis of Design Only. Final product shall be equivalent Japanese standard manufacturer product".\nHowever, typical Japanese manufacturers do not produce transformer units similar to pad mounts.\nPlease be submit Japanese product catalog sheet.\n\nFor switchgear for 13.8kV, JIS-C-62271-200 or JME1425 is the Japanese standard for manufacturing.\nJIS-C-4620 is for 6.6kV and should not be used as a reference.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 8, 10, 58),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842E83240>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E83600>},
#  {'id': '10742675',
#   'spec': 'n/a',
#   'sheet': 'P-120, P-121D',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please provide justification to locate the potable water backflow preventer and 100mm radon riser in FIRE PROTECTION 122 instead of MECHANICAL 123.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 11, 16),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E83B00>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E8C5E0>},
#  {'id': '10742677',
#   'spec': 'n/a',
#   'sheet': 'E-001',
#   'detail': 'Electrical Legends',
#   'critical': 'No',
#   'text': 'Provide home run symbol in the lighting and power plan drawings\n\nWiring already provided to several elec drawings.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 8, 11, 23),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E8D080>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E8D440>},
#  {'id': '10742708',
#   'spec': 'B1',
#   'sheet': 'E-001',
#   'detail': 'Electrical General Notes',
#   'critical': 'No',
#   'text': 'There is no hazardous area notes in the general notes.\nThis facility included that RM119 paint room area and RM120B O2RM (See GI101 Occupant Load chart).\n\nPlease refer to the design analysis 14.6.2.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 8, 12, 47),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E8D990>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E8DD50>},
#  {'id': '10742722',
#   'spec': 'n/a',
#   'sheet': 'P-503',
#   'detail': 'M9, M16, & G9',
#   'critical': 'No',
#   'text': 'These 3 details seem to describe the same compressed air connection station. Please reconcile and show only one detail.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 13, 20),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E8E250>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E8E980>},
#  {'id': '10742737',
#   'spec': 'n/a',
#   'sheet': 'P-601',
#   'detail': None,
#   'critical': 'No',
#   'text': 'PLUMBING FIXTURE SCHEDULE, please change ADA COMPLIANT TO ABA COMPLIANT in the table header.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 13, 32),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E8F150>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E8F880>},
#  {'id': '10742739',
#   'spec': 'n/a',
#   'sheet': 'ES-001',
#   'detail': 'Electrical Site Plan',
#   'critical': 'No',
#   'text': 'The main service feeder and FP feeder lines are drawn passing straight under the building from the 300kVA padmounted XFMR to the Elec RM and FP RM, but from an operational and maintenance standpoint. We recommend more functional method to run them from outside the building and provide a handhole in the middle.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 8, 13, 33),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E98090>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E987C0>},
#  {'id': '10742740',
#   'spec': 'n/a',
#   'sheet': 'E-101',
#   'detail': 'Elec 1st Floor Overall Lighting Plan',
#   'critical': 'No',
#   'text': 'RM122 Fire Protection RM (Fire Pump Room),  accordance with NFPA20,4.14.5, the emergency lighting shall be capable of maintaining the lighting level for a minimum of 2 hours and the intensity of illumination in the pump room(s) shall be 3.0 ft-candles (32.3 lux).',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 8, 13, 56),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E98D10>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E990D0>},
#  {'id': '10742759',
#   'spec': 'n/a',
#   'sheet': 'MH101D',
#   'detail': None,
#   'critical': 'No',
#   'text': "Please justify locating CU-1 so far away from CU-2 and CU-3. A single concrete equipment could be use for all 3 CU's if they are at the same location.",
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 8, 14, 34),
#   'status': 'Open',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E995D0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E9A070>},
#  {'id': '10744999',
#   'spec': 'n/a',
#   'sheet': 'M-601',
#   'detail': None,
#   'critical': 'No',
#   'text': "(1) Please justify the hugely oversized chilled and hot water coils in AHU-1, AHU-2, and AHU-3.\n\n(2) Please explain how the EWT (13.9 C) at the chiller become lower than the LWT (14.0 C) at the AHU's.\n\nPlease see attached for reference.",
#   'attachment': 'Comment_107449992.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 9, 10, 27),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E9AB10>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E9AED0>},
#  {'id': '10746810',
#   'spec': 'n/a',
#   'sheet': 'E-602',
#   'detail': 'K1 and K8',
#   'critical': 'No',
#   'text': 'For Pad-Mounted XFMR, in Kadena Design Guide 15.4.8(C)(5), KAB 18 CES/CEOFE had indicated a preference for Envirotemp FR3 dielectric flid in their pad-mounted XFMR.\nDrawing EP601 K1 and K8 do not describe this less-flammable type specification, but please confirm with KAB Navy or CES user about the insulating oil type for transformers.\n\nPlease confirm the spec 26.12.19.10.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 10, 6, 44),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Equipment',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842E9B6A0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842E9BA60>},
#  {'id': '10746877',
#   'spec': 'n/a',
#   'sheet': 'M-601',
#   'detail': None,
#   'critical': 'No',
#   'text': 'M-601 shows exhaust fans and VAV boxes in 277V/1ph and other equipment in 480V/3ph.\n\n277V and 480V are not commonly provided in Japan so local equipment manufacturers usually do not make equipment in 277V or 480V. Japanese standard voltages are 100/200/400V.\n\nPlease propose solutions and prepare to discuss in OBR meeting.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 10, 8, 1),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EA8270>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EA8630>},
#  {'id': '10746894',
#   'spec': 'n/a',
#   'sheet': 'M-601',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please remove the brand specify information in the AHU/DOAS schedule.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 10, 8, 22),
#   'status': 'Open',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EA8E00>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EA9530>},
#  {'id': '10746913',
#   'spec': 'n/a',
#   'sheet': 'TS100',
#   'detail': 'A1 Telecom Site Plan',
#   'critical': 'No',
#   'text': 'Accordance with UFC3-550-01,16.3.3 & 5-3.1(CHAPTER 5 NAVY SPECIFIC REQUIREMENTS) Pathway or KDG16.3.3 Duct Lines, A 3-cell fabric mesh inner duct is considered necessary for communication cable conduit for exterior pathway.\n\nAlthough there is no description of innerduct spec in the drawings, please confirm with base comm office and consider installing the innerduct.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 10, 8, 50),
#   'status': 'Open',
#   'discipline': 'Communications',
#   'coordinatingdiscipline': 'Communications',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EA9D00>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EAA0C0>},
#  {'id': '10746927',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'The data on the cost of generator sets is not very good, so please get a vendor quote and use it. Please also provide the cost estimates.?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Ryuji Yamagami',
#   'date': datetime.datetime(2024, 4, 10, 9, 5),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842EAA5C0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EAA980>},
#  {'id': '10747009',
#   'spec': 'n/a',
#   'sheet': 'E-601 and M-601',
#   'detail': 'A1 Electrical One-Line Diagram',
#   'critical': 'No',
#   'text': '[Nominal voltage issues when using Japanese electrical motorized equipment]\n\nE-601 main XFMR provided voltage rate 480/277V 3P4W and M-601 Mechanical Schedule provided also voltage rate accordance with 480/277V.\n\nOne concerning that if Japanese motorized equipment install to the facility, typical JPN products do not covered the 480/277V, but they produced general used only 415/240V or 460/245V in Japan.\n\nWhen procuring Japanese products, we believe that sufficient confirmation and coordination with the base side and mechanical engineers is necessary.\nPlease discuss at OBR at an early stage how to proceed with this plan.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 10, 10, 51),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Mechanical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EAAED0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EAB290>},
#  {'id': '10747151',
#   'spec': 'n/a',
#   'sheet': 'P-503',
#   'detail': 'A12',
#   'critical': 'No',
#   'text': 'Please revise the callout in Detail A12 to not show the brand information (KAESER MODEL KCF-50).',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 10, 13, 45),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EAB790>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EABEC0>},
#  {'id': '10747160',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': '(1) Please remove "COMPRESSED AIR AND" from the Detail title C1 on P-130 and revise the block title accordingly. Please see attached for reference.\n\n(2) Please provide an overall plan for the compressed air system.\n\n(3) Please provide enlarged plan and section views of the air the compressor room near Grid 4E.',
#   'attachment': 'Comment_10747160.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 10, 14, 7),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB06D0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB0E00>},
#  {'id': '10747190',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'The performance of HWP-1 and HWP-2 in the design analysis (Page 984 of 1702) do not match the ones in the schedule on M-601.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 10, 15, 6),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB15D0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB1990>},
#  {'id': '10749494',
#   'spec': 'n/a',
#   'sheet': 'M-601',
#   'detail': None,
#   'critical': 'No',
#   'text': 'In the AHUs/DOAS Schedule, the supply fan airflows of AHU-1, AHU-2, and DOAS-1 match the Actual Airflows in the cutsheets; however, the supply fan airflow of AHU-3 does not--Standard Airflow is shown instead in the schedule.\n\nPlease correct.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 11, 9, 31),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB2160>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB2520>},
#  {'id': '10749536',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please provide section views for the mechanical rooms.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 11, 9, 59),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB2CF0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB30B0>},
#  {'id': '10749567',
#   'spec': 'n/a',
#   'sheet': 'MH102D',
#   'detail': None,
#   'critical': 'No',
#   'text': 'A round gravity intake ventilator (IV-1) is included on Page 1062 of 1702 in the Design Analysis; however, it is not tagged on MH102D (near Grid 2.7G).\n\nPlease tag the ventilator and provide a schedule on M-601.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 11, 10, 20),
#   'status': 'Closed',
#   'discipline': 'Mechanical',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB3880>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB3C40>},
#  {'id': '10752222',
#   'spec': 'n/a',
#   'sheet': 'T-101 and T-102',
#   'detail': '1st and 2nd Floor Overall Telecom Plan',
#   'critical': 'No',
#   'text': 'Provide general telecom related outlets and equipment on the drawings. And also provide general sheets notes and keynotes information to the plans.\nThere are no information about general telecom outlet and other equipment location plan in the drawings.\n\nAvoid providing blank sheets.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 12, 11, 34),
#   'status': 'Open',
#   'discipline': 'Communications',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB84A0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB8860>},
#  {'id': '10752225',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Add 15% spare load to the load estimate sheet.',
#   'attachment': None,
#   'docref': 'Design Analysis 10.3 Interior Power',
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 12, 11, 38),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Planning - Plan Formulation',
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB8E00>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB91C0>},
#  {'id': '10752227',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'This is the same comment as comment status ID: 10658915 (Concept Design Review).\n\nThe Note box of the Labor tab, the source is written as the Sekisan Shiryo 2016. We recommend using the latest version.',
#   'attachment': '10658915.pdf',
#   'docref': None,
#   'author': 'Ayako Fuchino',
#   'date': datetime.datetime(2024, 4, 12, 11, 47),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB96C0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EB9A80>},
#  {'id': '10752233',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': "Please provide the plans, design analysis and design drawings required for each phase of the design plan according to JED's design guide.\nA clipping of the latest JED Design Guide is attached for your reference.",
#   'attachment': 'Reference_Japan_District_Design_Guide_v7_FEB_2023.pdf',
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 12, 12, 58),
#   'status': 'Open',
#   'discipline': 'General',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans and Specs',
#   'evaluations': <Element 'evaluations' at 0x0000025842EB9F80>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EBA340>},
#  {'id': '10752384',
#   'spec': 'n/a',
#   'sheet': 'S-101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'What is the purpose of the tie beams that run diagonally between B/1 & C/2, C/2 & D/1, E/1 & F/2, and F/2 & H/1? \n\nAre these intended to be seismic ties? Are the tie beams and grade beams parallel to the grid lines insufficient to restrain the pile cap?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Joel Reyes',
#   'date': datetime.datetime(2024, 4, 12, 17, 50),
#   'status': 'Open',
#   'discipline': 'Structural',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans and Specs',
#   'evaluations': <Element 'evaluations' at 0x0000025842EBA840>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EBAC50>},
#  {'id': '10752385',
#   'spec': 'n/a',
#   'sheet': 'S-101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Multiple pile caps are now shown with ties in only \n one direction. Will the reinforcing in the slab be designed to provide restraint?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Joel Reyes',
#   'date': datetime.datetime(2024, 4, 12, 17, 53),
#   'status': 'Open',
#   'discipline': 'Structural',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans and Specs',
#   'evaluations': <Element 'evaluations' at 0x0000025842EBB150>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EBB510>},
#  {'id': '10752390',
#   'spec': 'n/a',
#   'sheet': 'S-101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Currently, the drawings show the construction sequence as the walls being constructed to full height. Then the soil is backfilled, recompacted, and the slab-on-grade poured. With the amount of rooms, corridors, and compartments, this may be difficult to construct. To be discussed.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Joel Reyes',
#   'date': datetime.datetime(2024, 4, 12, 18, 35),
#   'status': 'Open',
#   'discipline': 'Structural',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans and Specs',
#   'evaluations': <Element 'evaluations' at 0x0000025842EBBA10>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EBBDD0>},
#  {'id': '10754956',
#   'spec': 'n/a',
#   'sheet': 'E-101C and E-705',
#   'detail': 'First Floor Lighting Plan-Area C',
#   'critical': 'No',
#   'text': 'Lighting fixtures for RM118 Battery Shop and RM118A, 118B battery storages. \nE-705 C1 and C1E noted LED enclosed and gasketed surface light fixture, but UFC 3-520-05, 2-4.3 Lighting described that "Install battery room lighting fixtures that are pendant or wall mounted, and do not provide a collection point for explosive gases".\n\nPlease consider requirement of UFC3-520-05.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 15, 13, 47),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Equipment',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EC4360>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EC4720>},
#  {'id': '10754989',
#   'spec': 'n/a',
#   'sheet': 'E-101 and E-101C',
#   'detail': 'B2 OVERALL FIRST FLOOR LIGHTING PLAN',
#   'critical': 'No',
#   'text': 'Lighting switches located inside of RM118A and RM118B battery storages.\n\nUFC3-520-05,2-4.3 required that receptacles and lighting switches should be located outside of the battery area.\n\nPlease re-consider about location of the switches of the battery storage area.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 15, 14, 5),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EC4C70>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EC5030>},
#  {'id': '10755028',
#   'spec': 'n/a',
#   'sheet': 'P-121C',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please provide a sink to Battery Shop 118/118A/118B per P-8A POSEIDON FACILITIES REQUIREMENT DOCUMENT, D809-00219-1_Facilities_Rqmts_doc_Re.pdf (Page 74 of 112).',
#   'attachment': 'Comment_10755028.pdf',
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 15, 14, 18),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EC5530>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EC5FD0>},
#  {'id': '10755088',
#   'spec': 'n/a',
#   'sheet': 'P-121C',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please provide emergency eyewash/shower in the battery shop per UFC 3-520-05 STATIONARY AND MISSION BATTERIES, Section 2-5.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 15, 14, 37),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EC6A70>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EC7510>},
#  {'id': '10755123',
#   'spec': 'n/a',
#   'sheet': 'M-402',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Keynote #1 says "DOAS UNITS TO BE MOUNTED ON 100 MM CONCRETE PADS ON THE FLOOR."\n\nPlease change the concrete pads height to 150mm.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Yat Hung Chan',
#   'date': datetime.datetime(2024, 4, 15, 15, 19),
#   'status': 'Open',
#   'discipline': 'Plumbing',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EC7FB0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECC720>},
#  {'id': '10757241',
#   'spec': 'n/a',
#   'sheet': 'E-101 and E-201',
#   'detail': 'B2 Overall First Floor Lighting and Power Plan',
#   'critical': 'No',
#   'text': 'RM112 mentioned "HAZMAT" storage.\nPlease ask and confirm with the NAVY user what kind of hazmat material will be stored to the RM112.\n\nDepending on the hazardous materials stored in this room, the NEC 500 series may be applied, such as explosion-proof lighting fixture, receptacle,  and wiring system.\n\nIf the room is covered by the NEC 500 series, please add a description of the explosion-proof specifications to the electrical notes, legends, and drawings.\nPlease also provide detailed drawings of explosion proof electrical construction examples.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 16, 9, 21),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECCEF0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECD620>},
#  {'id': '10757267',
#   'spec': 'n/a',
#   'sheet': 'E-201',
#   'detail': 'B2 Overall First Floor Power Plan',
#   'critical': 'No',
#   'text': 'It is likely that an eyewash/shower will be installed in the battery shop area, but please coordinate with the mech engineer if a receptacle etc. will be required.\nRefer to the UFC3-520-05, 2-5 Emergency facilities.\n\n\nIf these facilities are activated, please confirm with Navy users and FP engineers to see if emergency calls to the fire station or warning lights are required. However, if these life safety equipment is supported by FP or mech engineer, please consider providing electrical support if necessary.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 16, 9, 53),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Fire Protection/Life Safety',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECDBC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECDF80>},
#  {'id': '10757288',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': "The numbers of structure beam and girder on the takeoff sheet don't match with the drawing S-102 and S-103. And please verify these sizes to match with the drawing S-604. These sm sizes on takeoff sheet don't match with S-604 schedule.",
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 26),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECE480>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECE840>},
#  {'id': '10757289',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please verify the number of columns.  The takeoff sheet shows 9 while the drawing S-101 shows 18. There are 4 different sizes of columns are counted on MII but there is only C1 shows on drawing S-603 concrete column schedule.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 26),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECED40>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECF100>},
#  {'id': '10757291',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Only 150 thickness concrete slab is listed on the drawing S-602 while 150, 250 and 350 are counted on MII. There is no standard slab and grade listed on takeoff sheet. Please be consistent with the drawing, MII and takeoff-sheet.  And there is also "Concrete slab, Elevated. S3 – 200MM THK" listed under Superstructure/Floor Construction/Floor Decks and Slabs on MII.   Is this second floor slab? If so, please add note for clarification and verify the floor area.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 28),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECF600>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ECF9C0>},
#  {'id': '10757293',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please be consistent overall that the number of structural items and their names should match among the takeoff sheet, drawing and MII data.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 32),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ECFEC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED42C0>},
#  {'id': '10757301',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': "The number of exterior single door count doesn't match between MII and the drawing (21 vs 8).",
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 44),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED47C0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED4B80>},
#  {'id': '10757302',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'The exterior Wall thickness shows 300mm on A-101 but MII counts 150mm and 250mm.  the takeoff shows 400mm thickness. And the name on takeoff sheet noted "exterior precast wall" and are they precast not cast-in-place concrete?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 45),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED5080>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED5440>},
#  {'id': '10757303',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please use the same names for "Metal stud Partitions" on MII to match with the drawing A-501 for clarification.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 46),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED5940>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED5D00>},
#  {'id': '10757304',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Where is the exterior hangar door located on the drawing? (the source tag 083416100300)',
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 47),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED6200>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED65C0>},
#  {'id': '10757305',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': "The sizes and numbers of pile cap listed on takeoff sheet don't match with S-101 and S-602 pile schedule.",
#   'attachment': None,
#   'docref': None,
#   'author': 'Naoko Kubota',
#   'date': datetime.datetime(2024, 4, 16, 10, 49),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': 'Cost Engineering',
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED6AC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED6E80>},
#  {'id': '10757486',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please ensure that any attachments for 01 33 29 are included as well.\n \nAtt A-HPSB checklist\nAtt B-Third-Party Certification documents/forms\n\nThe names for these attachments may be tailored as the team sees fit.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Michael Teller',
#   'date': datetime.datetime(2024, 4, 16, 13, 21),
#   'status': 'Open',
#   'discipline': 'Sustainability',
#   'coordinatingdiscipline': 'Sustainability',
#   'doctype': 'Specifications',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED7380>,
#   'backchecks': <Element 'backchecks' at 0x0000025842ED7740>},
#  {'id': '10757491',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'FIO - ensure that "S" submittals which support project sustainability HPSB & TPC goals are noted as such in the 01 33 00-B Submittal register for the next design milestone.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Michael Teller',
#   'date': datetime.datetime(2024, 4, 16, 13, 23),
#   'status': 'Open',
#   'discipline': 'Sustainability',
#   'coordinatingdiscipline': 'Sustainability',
#   'doctype': 'Specifications',
#   'evaluations': <Element 'evaluations' at 0x0000025842ED7C40>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE0040>},
#  {'id': '10757515',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'For the next submittal, please ensure that the JED cover sheet is used and the information is filled in accordingly.',
#   'attachment': 'SPECS_Cover.docx',
#   'docref': None,
#   'author': 'Sherwin Edquiban',
#   'date': datetime.datetime(2024, 4, 16, 13, 47),
#   'status': 'Open',
#   'discipline': 'Specifications',
#   'coordinatingdiscipline': 'Specifications',
#   'doctype': 'Specifications',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE0540>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE0900>},
#  {'id': '10757518',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'check General notes, remove references to other installations. (i.e. note #3 YAB, etc.)\n\ncheck for consistent drawing sheet references also. i.e. there is currently no A-002 in the set but is referenced in the general notes.',
#   'attachment': None,
#   'docref': 'A-001',
#   'author': 'Michael Teller',
#   'date': datetime.datetime(2024, 4, 16, 13, 49),
#   'status': 'Open',
#   'discipline': 'Architectural',
#   'coordinatingdiscipline': 'Architectural',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE0E50>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE1260>},
#  {'id': '10757538',
#   'spec': '01 20 00',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'If it has not been held already, please coordinate a meeting to discuss/clarify the CLIN/POP sometime before the Intermediate Submittal',
#   'attachment': '00_10_00_Uncommon_New_Work_Example.docx',
#   'docref': None,
#   'author': 'Sherwin Edquiban',
#   'date': datetime.datetime(2024, 4, 16, 14, 51),
#   'status': 'Open',
#   'discipline': 'Project Management',
#   'coordinatingdiscipline': 'Contracting',
#   'doctype': 'Specifications',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE17B0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE1B70>},
#  {'id': '10757540',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please coordinate the completion of the Construction Memo with Construction and sent to the AE before the Intermediate Submittal.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Sherwin Edquiban',
#   'date': datetime.datetime(2024, 4, 16, 14, 54),
#   'status': 'Closed',
#   'discipline': 'Project Management',
#   'coordinatingdiscipline': 'Construction Management',
#   'doctype': 'Other',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE2070>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE2430>},
#  {'id': '10759890',
#   'spec': 'n/a',
#   'sheet': 'E-101D and E-102D',
#   'detail': '1st and 2nd Floor Lighting Plan',
#   'critical': 'No',
#   'text': 'Accordance with UFC3-490-06 "Elevator" 6-2.1 Hoistway Lighting, please provide hoistway pit lighting minimum 10fc at the pit floor and at a minimum of every 10feet(3m) vertically up the hoistway.\nAnd also provide two -3way switches inside the elevator hoistway, at a height of 4feer(1.2m) above the top and bottom elevator landings.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 17, 9, 43),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE2CA0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE3060>},
#  {'id': '10759902',
#   'spec': 'n/a',
#   'sheet': 'E-201',
#   'detail': 'Overall 1st Floor Lighting Plan',
#   'critical': 'No',
#   'text': 'Accordance with UFC3-490-06,6-3 elevator hoistway pit, please provide a separate branch circuit supplying power to the hoistway pit sump pump receptacle and also provide the pit GFCI receptacles.\n\nPlease refer to the UFC3-490-06 related section.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 17, 9, 53),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE35B0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EE3970>},
#  {'id': '10759918',
#   'spec': 'n/a',
#   'sheet': 'E-202D',
#   'detail': '2nd Floor Power Plan - Area D',
#   'critical': 'No',
#   'text': 'Please consider the UFC3-490-06, 6-1.2 and 6-1.2.1, provide elevator disconnecting means on the wall inside the MR and CR, and provide a shunt trip circuit breaker that in case of fire protection sprinkler activated in fire.\n\nPlease confirm the UFC3-490-06, 6-1 Elevator MR, CR and MS.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Atsushi Nagamine',
#   'date': datetime.datetime(2024, 4, 17, 10, 4),
#   'status': 'Open',
#   'discipline': 'Electrical',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842EE3EC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EF02C0>},
#  {'id': '10759963',
#   'spec': '09 90 00',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': "Please ensure that the lead concentrations mentioned in this specification match what's stated in 01 57 19.01 to avoid confusion later.",
#   'attachment': None,
#   'docref': None,
#   'author': 'Steven Mow',
#   'date': datetime.datetime(2024, 4, 17, 10, 42),
#   'status': 'Open',
#   'discipline': 'Environmental',
#   'coordinatingdiscipline': None,
#   'doctype': 'Specifications',
#   'evaluations': <Element 'evaluations' at 0x0000025842EF07C0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842EF0B80>},
#  {'id': '10759965',
#   'spec': '01 57 19.01-A',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': '01 57 19-A applies to Yokota AB, not Kadena. Please remove from the package.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Steven Mow',
#   'date': datetime.datetime(2024, 4, 17, 10, 43),
#   'status': 'Open',
#   'discipline': 'Environmental',
#   'coordinatingdiscipline': None,
#   'doctype': 'Specifications',
# ...
#   'evaluations': <Element 'evaluations' at 0x0000025842F0E1B0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F0E570>},
#  {'id': '10765151',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please look at the major subcontractors on the project. Currently a 4% markup is being used for FOOH and I anticipate that this would be low.  If we assume at a minimum that a major subcontractor (i.e. HVAC, Electrical, etc) has a superintendent and a quality control manager / Engineer on the job for say 6 months.  The costs would be roughly 6 months x 2 personnel x approx 1 million yen. This would equate to 12 million yen.  This does not account for their trailer expenses, supplies, truck expenses, possible admin/clerk, etc.  I would expect it may be in the range of 20 million yen in FOOH expenses, or about 8%.  Please review and adjust as needed.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Simon Jackson',
#   'date': datetime.datetime(2024, 4, 19, 10, 4),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': None,
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842F0EA70>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F0EE30>},
#  {'id': '10765161',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Please review the quantity of VAV boxes in the estimate.  The schedule shows 22 and the estimate has 44.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Simon Jackson',
#   'date': datetime.datetime(2024, 4, 19, 10, 17),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': None,
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842F0F330>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F0F6F0>},
#  {'id': '10765195',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'What is included under the special costs?  Is this PCAS, cybersecurity, and cybersecurity commissioning? If it is can you separate these costs out under this folder.  For cybersecurity there are typically 4 platforms that can be secured.  How many platforms are we anticipating on this project, and what allowance is included?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Simon Jackson',
#   'date': datetime.datetime(2024, 4, 19, 10, 55),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': None,
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842F0FBF0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F0FFB0>},
#  {'id': '10765196',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Is there an allowance for sustainability and Leed which is typically around 2% of the cost of the facility, or will this facility not have any of these measures?',
#   'attachment': None,
#   'docref': None,
#   'author': 'Simon Jackson',
#   'date': datetime.datetime(2024, 4, 19, 10, 57),
#   'status': 'Open',
#   'discipline': 'Cost Engineering',
#   'coordinatingdiscipline': None,
#   'doctype': 'Cost Estimate',
#   'evaluations': <Element 'evaluations' at 0x0000025842F144F0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F148B0>},
#  {'id': '10770794',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Hydraulic calculations "Notes" "indicate that an additional 1,900 LPM demand has been included at the direction of the Base Personnel to account for an industrial parts washer that may be in use during sprinkler operation." Include this information in the FP design analysis for the water supply requirements.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 39),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F14E00>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F151C0>},
#  {'id': '10770795',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Section 7.4.1 states that a fire pump is planned to accommodate the pressure differential between what is supplied and what will be required. Section 7.4.9 states a fire pump will not be required. Please clarify.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 41),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F15710>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F15E40>},
#  {'id': '10770796',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Section 7.3.7 refers to IFC 3-600-01. Please verify.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 41),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F16390>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F16750>},
#  {'id': '10770797',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Section 7.2.6 states the permitted allowable area is 4,633 SM and provided 4,633 SM. Verify the actual provide building area and include the Frontage Increase Factor from IBC Table 506.3.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 41),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F16CA0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F17060>},
#  {'id': '10770798',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'UFC 3-520-05 Stationary and Mission Batteries is listed in the references as a applicable document. Section 7.3.9 Batteries refers to NFPA 855 as an applicable standard. Verify the applicable requirements are included in this section.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 42),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F175B0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F17970>},
#  {'id': '10770799',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Section 7.2.9 states a 2-hour separation is required for the Battery Storage area. Is this a requirement from UFC 3-520-05 or NFPA 855? Provide the code reference in the design analysis.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 42),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F17EC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F202C0>},
#  {'id': '10770800',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Provide the code reference for the separation requirement for the paint booth and Aviation Life Support O2 Room in Section 7.2.9.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 23, 14, 52),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Design Analysis',
#   'evaluations': <Element 'evaluations' at 0x0000025842F20810>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F20BD0>},
#  {'id': '10773028',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'A fire alarm input/output matrix is not provided on the plans.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 9, 0),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F21120>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F214E0>},
#  {'id': '10773034',
#   'spec': 'n/a',
#   'sheet': None,
#   'detail': None,
#   'critical': 'No',
#   'text': 'Fire alarm/MNS wiring diagram not provided on the plans.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 9, 2),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F21A30>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F21DF0>},
#  {'id': '10773077',
#   'spec': 'n/a',
#   'sheet': 'FA101 & FA102',
#   'detail': None,
#   'critical': 'No',
#   'text': 'UFC 4-021-01 section 4-6.2.1 requires LED text signs to be provided over the door to each egress stairwell and over (or adjacent to the substantial means of egress from the level of discharge.  Review the MNS text sign locations are in accordance with this requirement.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 9, 27),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F22340>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F22A70>},
#  {'id': '10773091',
#   'spec': 'n/a',
#   'sheet': 'FA101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Plans show smoke detectors in 118A & 118B battery rooms. UFC 3-520-05 section 2-6 does not require smoke detection. Please address and clarify the requirement for smoke detection for these battery rooms in the Design Analysis.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 9, 44),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F22FC0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F23380>},
#  {'id': '10773117',
#   'spec': 'n/a',
#   'sheet': 'FA101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Plans show the MNS/LOC in the Security Room 101 and second floor corridor.. UFC 4-021-01 section 4-5.1 requires the LOC to be located to allow emergency response forces and building occupants access to the MSN and originate messages in emergency situations. For Navy projects no more than one LOC should be provided.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 9, 56),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F238D0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F23CE0>},
#  {'id': '10773181',
#   'spec': '21 30 00',
#   'sheet': 'FX101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Plans show a backflow preventer only in Room 122. No fire pump is shown. Documents including Design analysis, Plan notes, and Specs mention fire pump.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 11, 15),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans and Specs',
#   'evaluations': <Element 'evaluations' at 0x0000025842F28270>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F28630>},
#  {'id': '10773218',
#   'spec': 'n/a',
#   'sheet': 'FA101 & FA102',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Design analysis section 7.5.3 states that CO detectors will not be provided for this project. Please delete CO detector symbol for the drawing Legend.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 12, 33),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F28B80>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F28F40>},
#  {'id': '10773229',
#   'spec': 'n/a',
#   'sheet': 'GI001',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Clarify conflict regarding the fire pump. Water Supply & Summary of FP Features notes indicate a fire pump will be provided. Fire Pump notes indicate no fire pump will be required.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 14, 1),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': None,
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F29490>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F29850>},
#  {'id': '10773243',
#   'spec': 'n/a',
#   'sheet': 'E102 & 102C',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Exit sign not shown on second floor East exit Stairwell.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 14, 27),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F29DA0>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F2A1B0>},
#  {'id': '10773259',
#   'spec': 'n/a',
#   'sheet': 'E101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Parts Storage Room 113 has two doors and is a large size room. Recommend providing an exit sign at the door leading to the exterior.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 15, 16),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': 'Electrical',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F2A700>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F2AAC0>},
#  {'id': '10773265',
#   'spec': 'n/a',
#   'sheet': 'CS101',
#   'detail': None,
#   'critical': 'No',
#   'text': 'Plans show the post indicating valve (PIV) between the doors of the Fire Protection Room 122 and Elevator Equipment Room 124. Review the location of the PIV is in accordance with NFPA 24 para 6.2.9 and provides proper access, clearances, and protection from mechanical damage.',
#   'attachment': None,
#   'docref': None,
#   'author': 'Tony Blackburn',
#   'date': datetime.datetime(2024, 4, 24, 15, 41),
#   'status': 'Open',
#   'discipline': 'Fire Protection/Life Safety',
#   'coordinatingdiscipline': 'Civil',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F2B010>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F2B740>},
#  {'id': '10788191',
#   'spec': 'n/a',
#   'sheet': 'A-311',
#   'detail': '2',
#   'critical': 'No',
#   'text': 'February Concept submittal shows roof insulation above slab. April resubmittal shows roof insulation below slab. As shown using Japanese insulation this does not meet US fire/flame spread rating. Using US insulation will increase procurement time and construction cost. Propose alternative design that meets US ratings that is most cost effective',
#   'attachment': None,
#   'docref': None,
#   'author': 'Gregory Church',
#   'date': datetime.datetime(2024, 5, 2, 9, 50),
#   'status': 'Open',
#   'discipline': 'Architectural',
#   'coordinatingdiscipline': 'Fire Protection/Life Safety',
#   'doctype': 'Plans',
#   'evaluations': <Element 'evaluations' at 0x0000025842F2BC90>,
#   'backchecks': <Element 'backchecks' at 0x0000025842F34090>}]

# %%
df = pd.DataFrame(convo.dump())

# %%
dump_path = 'comments_dump.xlsx'
df.to_excel(dump_path, index=False)
